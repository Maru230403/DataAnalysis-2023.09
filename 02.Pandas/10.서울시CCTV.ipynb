# %% [markdown]
# ### 2.10 서울시 구별 CCTV 현황 분석
# - 서울시 자치구 연도별 CCTV 설치 현황
# - 서울시 주민등록인구(구별)통계

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1.CCTV 데이터

# %%
cctv = pd.read_csv('data/서울시 자치구 년도별 CCTV 설치 현황_230630기준.csv',
                    encoding='EUC-KR', index_col='구분',thousands=',')              
cctv.head()
# Out:
#      Unnamed: 0     총계  2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  \
# 구분
# 계           NaN  92991    5896.0   3927   6416   8812  11598  10887  13083
# 종로구         1.0   1966     553.0    103    160    130    144    150     67
# 중 구         2.0   2584     217.0     77    236    240    372    386    155
# 용산구         3.0   2970      87.0     68     83    295    491    115    322
# 성동구         4.0   4175     157.0    110    366    281    942    457    643
#
#      2020년  2021년  2022년   2023년
# 구분
# 계    11803   9396   9302  1871.0
# 종로구    233     88    207   131.0
# 중 구    361    403    137     0.0
# 용산구    623    422    464     0.0
# 성동구    485    367    232   135.0

# %%
cctv.drop(columns=['Unnamed: 0','2023년','총계'],inplace=True)
cctv.drop(['계'], inplace=True)    # '계' 행 지우기
cctv.head(3)
# Out:
#      2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년
# 구분
# 종로구     553.0    103    160    130    144    150     67    233     88    207
# 중 구     217.0     77    236    240    372    386    155    361    403    137
# 용산구      87.0     68     83    295    491    115    322    623    422    464

# %%
# 결측치가 있는지 확인
cctv['2014년 이전'].isna().sum()
# Out:
# 1

# %%
# 결측치를 0으로 대체하고, 타입을 정수로 변경
cctv['2014년 이전'] = cctv['2014년 이전'].fillna(0).astype(int)
cctv.head()
# Out:
#      2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년
# 구분
# 종로구       553    103    160    130    144    150     67    233     88    207
# 중 구       217     77    236    240    372    386    155    361    403    137
# 용산구        87     68     83    295    491    115    322    623    422    464
# 성동구       157    110    366    281    942    457    643    485    367    232
# 광진구       130    176     95     40    666    460    712    190    738    273

# %%
cctv['CCTV댓수'] = cctv.sum(axis=1)
cctv.head(3)
# Out:
#      2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 구분
# 종로구       553    103    160    130    144    150     67    233     88    207
# 중 구       217     77    236    240    372    386    155    361    403    137
# 용산구        87     68     83    295    491    115    322    623    422    464
#
#      CCTV댓수
# 구분
# 종로구    1835
# 중 구    2584
# 용산구    2970

# %%
cctv['최근증가율'] = (cctv.loc[:, '2020년':'2022년'].sum(axis=1) / cctv['CCTV댓수'] * 100).round(2)
cctv.head(3)
# Out:
#      2014년 이전  2014년  2015년  2016년  2017년  2018년  2019년  2020년  2021년  2022년  \
# 구분
# 종로구       553    103    160    130    144    150     67    233     88    207
# 중 구       217     77    236    240    372    386    155    361    403    137
# 용산구        87     68     83    295    491    115    322    623    422    464
#
#      CCTV댓수  최근증가율
# 구분
# 종로구    1835  28.77
# 중 구    2584  34.87
# 용산구    2970  50.81

# %%
cctv.drop(columns=['2014년 이전'] + '2014년	2015년	2016년	2017년	2018년	2019년	2020년	2021년	2022년'.split(),
            inplace=True)
cctv.head()
# Out:
#      CCTV댓수  최근증가율
# 구분
# 종로구    1835  28.77
# 중 구    2584  34.87
# 용산구    2970  50.81
# 성동구    4040  26.83
# 광진구    3480  34.51

# %%
#' 중 구' 의 blank 없애기
cctv.index = cctv.index.str.replace(' ', '')
cctv.index[1]
# Out:
# '중구'

# %% [markdown]
# #### 2. 인구 데이터 정리하기

# %%
ps = pd.read_csv('data/서울시구별주민등록인구_20230912141751.csv',
                skiprows=1)
ps.head()
# Out:
#   동별(1) 동별(2)  세대 (세대)    계 (명)  한국인 (명)  등록외국인 (명)  세대당인구 (명)  65세이상고령자 (명)  \
# 0    합계    소계  4463385  9668008  9426404     241604       2.11       1690961
# 1    합계   종로구    72679   152212   141060      11152       1.94         28265
# 2    합계    중구    63862   131390   120963      10427       1.89         25353
# 3    합계   용산구   109735   232482   217756      14726       1.98         39478
# 4    합계   성동구   133513   287240   280240       7000       2.10         48238
#
#    세대 (세대).1  계 (명).1  한국인 (명).1  등록외국인 (명).1  인구밀도
# 0    4469158  9659322    9414093       245229     2
# 1      72507   151349     140397        10952     2
# 2      64375   132054     121441        10613     2
# 3     109679   232069     217288        14781     2
# 4     133484   286564     279374         7190     2

# %%
ps.drop(columns=['동별(2)','세대 (세대).1',	'계 (명).1','한국인 (명).1','등록외국인 (명).1','인구밀도'], inplace=True)
ps.head()
# Out:
#   동별(1)  세대 (세대)    계 (명)  한국인 (명)  등록외국인 (명)  세대당인구 (명)  65세이상고령자 (명)
# 0    합계  4463385  9668008  9426404     241604       2.11       1690961
# 1    합계    72679   152212   141060      11152       1.94         28265
# 2    합계    63862   131390   120963      10427       1.89         25353
# 3    합계   109735   232482   217756      14726       1.98         39478
# 4    합계   133513   287240   280240       7000       2.10         48238

# %%
ps['외국인비율'] = (ps['등록외국인 (명)'] / ps['계 (명)'] * 100).round(2)  
ps.head()
# Out:
#   동별(1)  세대 (세대)    계 (명)  한국인 (명)  등록외국인 (명)  세대당인구 (명)  65세이상고령자 (명)  외국인비율
# 0    합계  4463385  9668008  9426404     241604       2.11       1690961   2.50
# 1    합계    72679   152212   141060      11152       1.94         28265   7.33
# 2    합계    63862   131390   120963      10427       1.89         25353   7.94
# 3    합계   109735   232482   217756      14726       1.98         39478   6.33
# 4    합계   133513   287240   280240       7000       2.10         48238   2.44

# %%
ps['고령자비율'] = (ps['65세이상고령자 (명)'] / ps['계 (명)'] * 100).round(2)
ps.head()
# Out:
#   동별(1)  세대 (세대)    계 (명)  한국인 (명)  등록외국인 (명)  세대당인구 (명)  65세이상고령자 (명)  외국인비율  \
# 0    합계  4463385  9668008  9426404     241604       2.11       1690961   2.50
# 1    합계    72679   152212   141060      11152       1.94         28265   7.33
# 2    합계    63862   131390   120963      10427       1.89         25353   7.94
# 3    합계   109735   232482   217756      14726       1.98         39478   6.33
# 4    합계   133513   287240   280240       7000       2.10         48238   2.44
#
#    고령자비율
# 0  17.49
# 1  18.57
# 2  19.30
# 3  16.98
# 4  16.79

# %%
ps.drop(columns=['세대 (세대)','세대당인구 (명)'], inplace=True)
ps.head()
# Out:
#   동별(1)    계 (명)  한국인 (명)  등록외국인 (명)  65세이상고령자 (명)  외국인비율  고령자비율
# 0    합계  9668008  9426404     241604       1690961   2.50  17.49
# 1    합계   152212   141060      11152         28265   7.33  18.57
# 2    합계   131390   120963      10427         25353   7.94  19.30
# 3    합계   232482   217756      14726         39478   6.33  16.98
# 4    합계   287240   280240       7000         48238   2.44  16.79

# %%
pop = pd.read_csv('data/서울시구별주민등록인구_20230912141751.csv',skiprows=1, thousands=',')
pop.head(5)
# Out:
#   동별(1) 동별(2)  세대 (세대)    계 (명)  한국인 (명)  등록외국인 (명)  세대당인구 (명)  65세이상고령자 (명)  \
# 0    합계    소계  4463385  9668008  9426404     241604       2.11       1690961
# 1    합계   종로구    72679   152212   141060      11152       1.94         28265
# 2    합계    중구    63862   131390   120963      10427       1.89         25353
# 3    합계   용산구   109735   232482   217756      14726       1.98         39478
# 4    합계   성동구   133513   287240   280240       7000       2.10         48238
#
#    세대 (세대).1  계 (명).1  한국인 (명).1  등록외국인 (명).1  인구밀도
# 0    4469158  9659322    9414093       245229     2
# 1      72507   151349     140397        10952     2
# 2      64375   132054     121441        10613     2
# 3     109679   232069     217288        14781     2
# 4     133484   286564     279374         7190     2

# %%
pop = pop[['동별(2)','계 (명)','한국인 (명)','등록외국인 (명)','65세이상고령자 (명)']]
pop.head(3)
# Out:
#   동별(2)    계 (명)  한국인 (명)  등록외국인 (명)  65세이상고령자 (명)
# 0    소계  9668008  9426404     241604       1690961
# 1   종로구   152212   141060      11152         28265
# 2    중구   131390   120963      10427         25353

# %%
pop.columns = ['구별','인구수','내국인','외국인','고령자']
pop.head(3)
# Out:
#     구별      인구수      내국인     외국인      고령자
# 0   소계  9668008  9426404  241604  1690961
# 1  종로구   152212   141060   11152    28265
# 2   중구   131390   120963   10427    25353

# %%
# 첫번쨰 행 지우기
pop.drop([0], inplace=True)
pop.head(3)
# Out:
#     구별     인구수     내국인    외국인    고령자
# 1  종로구  152212  141060  11152  28265
# 2   중구  131390  120963  10427  25353
# 3  용산구  232482  217756  14726  39478

# %%
# 구별을 인덱스로 만들기
pop.set_index('구별', inplace=True)
pop.head(3)
# Out:
#         인구수     내국인    외국인    고령자
# 구별
# 종로구  152212  141060  11152  28265
# 중구   131390  120963  10427  25353
# 용산구  232482  217756  14726  39478

# %%
# 외국인 비율
pop['외국인 비율'] = (pop.외국인 / pop['인구수'] * 100).round(2)
pop['고령자 비율'] = (pop.고령자 / pop['인구수'] * 100).round(2)
pop.head(3)
# Out:
#         인구수     내국인    외국인    고령자  외국인 비율  고령자 비율
# 구별
# 종로구  152212  141060  11152  28265    7.33   18.57
# 중구   131390  120963  10427  25353    7.94   19.30
# 용산구  232482  217756  14726  39478    6.33   16.98

# %% [markdown]
# #### 3. CCTV 데이터와 POP 데이터 합치기

# %%
df = pd.merge(pop, cctv, left_index=True, right_index=True) # 둘다 index이기에 index 사용
df.head()
# Out:
#         인구수     내국인    외국인    고령자  외국인 비율  고령자 비율  CCTV댓수  최근증가율
# 종로구  152212  141060  11152  28265    7.33   18.57    1835  28.77
# 중구   131390  120963  10427  25353    7.94   19.30    2584  34.87
# 용산구  232482  217756  14726  39478    6.33   16.98    2970  50.81
# 성동구  287240  280240   7000  48238    2.44   16.79    4040  26.83
# 광진구  350925  336801  14124  54854    4.02   15.63    3480  34.51

# %%
pd.concat([cctv, pop], axis=1)
# Out:
#       CCTV댓수  최근증가율     인구수     내국인    외국인     고령자  외국인 비율  고령자 비율
# 종로구     1835  28.77  152212  141060  11152   28265    7.33   18.57
# 중구      2584  34.87  131390  120963  10427   25353    7.94   19.30
# 용산구     2970  50.81  232482  217756  14726   39478    6.33   16.98
# 성동구     4040  26.83  287240  280240   7000   48238    2.44   16.79
# 광진구     3480  34.51  350925  336801  14124   54854    4.02   15.63
# 동대문구    2750  28.18  354884  337574  17310   65154    4.88   18.36
# 중랑구     4193  42.38  389928  385003   4925   76116    1.26   19.52
# 성북구     4853  20.56  441855  430100  11755   78427    2.66   17.75
# 강북구     3321  50.11  296934  292762   4172   67056    1.41   22.58
# 도봉구     2126  64.06  312858  310509   2349   68114    0.75   21.77
# 노원구     2608  28.60  506989  502515   4474   93279    0.88   18.40
# 은평구     4653  27.53  468766  464871   3895   90556    0.83   19.32
# 서대문구    3445  27.46  321966  308437  13529   56785    4.20   17.64
# 마포구     2628  22.53  376542  365570  10972   56582    2.91   15.03
# 양천구     3890  26.17  442345  439219   3126   73522    0.71   16.62
# 강서구     3312  42.27  573711  568287   5424   98659    0.95   17.20
# 구로구     4653  36.15  417983  395183  22800   77259    5.45   18.48
# 금천구     2650  38.64  242467  229307  13160   43772    5.43   18.05
# 영등포구    4644  45.99  398999  376614  22385   66014    5.61   16.54
# 동작구     2664  31.38  390377  380201  10176   68766    2.61   17.62
# 관악구     5239  20.77  502628  487815  14813   83420    2.95   16.60
# 서초구     4995  37.32  408979  404831   4148   63328    1.01   15.48
# 강남구     7243  26.30  537817  532798   5019   83097    0.93   15.45
# 송파구     3154  25.97  663704  658006   5698  105161    0.86   15.84
# 강동구     3190  42.79  464027  459982   4045   79706    0.87   17.18

# %%
df.shape
# Out:
# (25, 8)

# %%
df.index.name = '구별'
df.head()
# Out:
#         인구수     내국인    외국인    고령자  외국인 비율  고령자 비율  CCTV댓수  최근증가율
# 구별
# 종로구  152212  141060  11152  28265    7.33   18.57    1835  28.77
# 중구   131390  120963  10427  25353    7.94   19.30    2584  34.87
# 용산구  232482  217756  14726  39478    6.33   16.98    2970  50.81
# 성동구  287240  280240   7000  48238    2.44   16.79    4040  26.83
# 광진구  350925  336801  14124  54854    4.02   15.63    3480  34.51

# %%
df.to_csv('data/서울시 구별 CCTV 인구 현황.csv')

# %%
pd.read_csv('data/서울시 구별 CCTV 인구 현황.csv').head()
# Out:
#     구별     인구수     내국인    외국인    고령자  외국인 비율  고령자 비율  CCTV댓수  최근증가율
# 0  종로구  152212  141060  11152  28265    7.33   18.57    1835  28.77
# 1   중구  131390  120963  10427  25353    7.94   19.30    2584  34.87
# 2  용산구  232482  217756  14726  39478    6.33   16.98    2970  50.81
# 3  성동구  287240  280240   7000  48238    2.44   16.79    4040  26.83
# 4  광진구  350925  336801  14124  54854    4.02   15.63    3480  34.51
