# %% [markdown]
# # 서울시 CCTV - 인구 시각화

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv('../02.Pandas/data/서울시 구별 CCTV 인구 현황.csv', index_col='구별')
df.head()
# Out:
#         인구수     내국인    외국인    고령자  외국인 비율  고령자 비율  CCTV댓수  최근증가율
# 구별
# 종로구  152212  141060  11152  28265    7.33   18.57   10797  45.48
# 중구   131390  120963  10427  25353    7.94   19.30    9593  56.49
# 용산구  232482  217756  14726  39478    6.33   16.98   15775  44.27
# 성동구  287240  280240   7000  48238    2.44   16.79   19915  51.76
# 광진구  350925  336801  14124  54854    4.02   15.63   15082  58.72

# %% [markdown]
# ##### 1. 자치구별 CCTV 설치댓수

# %%
df.CCTV댓수.plot(kind='barh')
plt.title(' 서울시 구별 CCTV 설치댓수');

# %%
# CCTV 댓수로 정렬하고, plt.barh() 로 그리기
sc = df['CCTV댓수'].sort_values()
plt.barh(sc.index, sc.values)
plt.title(' 서울시 구별 CCTV 설치댓수 정렬완료');

# %%
df.CCTV댓수.sort_values(ascending=False).plot(kind='barh')   
plt.title('서울시');

# %%
# Seabron으로 그리기
sns.barplot(data=df, y=df.index, x='CCTV댓수') 
plt.title('서울시 구별 CCTV 설치 댓수');

# %%
scr = df['CCTV댓수'].sort_values(ascending=False)
sns.barplot(y=scr.index, x=scr.values)
plt.title('서울시 구별 CCTV 설치댓수 정렬완료');

# %% [markdown]
# ##### 2. 구별 인당 CCTV 댓수 그리기 - plt.barh()

# %%
df['인당CCTV댓수'] = (df['CCTV댓수'] / df['인구수'])
df.head()
# Out:
#         인구수     내국인    외국인    고령자  외국인 비율  고령자 비율  CCTV댓수  최근증가율  인당CCTV댓수
# 구별
# 종로구  152212  141060  11152  28265    7.33   18.57   10797  45.48  0.070934
# 중구   131390  120963  10427  25353    7.94   19.30    9593  56.49  0.073012
# 용산구  232482  217756  14726  39478    6.33   16.98   15775  44.27  0.067855
# 성동구  287240  280240   7000  48238    2.44   16.79   19915  51.76  0.069332
# 광진구  350925  336801  14124  54854    4.02   15.63   15082  58.72  0.042978

# %%
sc = df['인당CCTV댓수'].sort_values()
plt.barh(sc.index, sc.values)
plt.title('구별 인당 CCTV 댓수');

# %%
# 센세 풀이
s = (df['CCTV댓수'] / df['인구수']).sort_values()
plt.barh(s.index, s.values)
plt.title('구별 인당 CCTV 댓수');
