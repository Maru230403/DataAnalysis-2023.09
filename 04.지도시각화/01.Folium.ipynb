# %% [markdown]
# ## Folium 지도 시각화
# - 설치
#     - conda activate base
#     - pip install folium

# %%
import folium
folium.__version__
# Out:
# '0.14.0'

# %% [markdown]
# - map 객체 만들기

# %%
# Open Street Map
map = folium.Map(location=[37.52272, 126.905131], zoom_start=14)       # 영등포시장역
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4defd041f14f71827518812d5116e57f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4defd041f14f71827518812d5116e57f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4defd041f14f71827518812d5116e57f = L.map(
#                 &quot;map_4defd041f14f71827518812d5116e57f&quot;,
#                 {
#                     center: [37.52272, 126.905131],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b70e16fb0c9d92c1d4bea5b17e87abd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4defd041f14f71827518812d5116e57f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - tileset 선택

# %%
# default tileset: Open Street Map
# Stamen Toner: 단계구분도(Choropleth)를 그릴 때 사용
map = folium.Map(location=[37.52272, 126.905131], zoom_start=14, tiles='Stamen Toner')       # 영등포시장역
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e4bd8c3e31ef846ecee102703cb8c92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e4bd8c3e31ef846ecee102703cb8c92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e4bd8c3e31ef846ecee102703cb8c92 = L.map(
#                 &quot;map_2e4bd8c3e31ef846ecee102703cb8c92&quot;,
#                 {
#                     center: [37.515556, 126.907778],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b858269950f38b65d589648ea9ef36db = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e4bd8c3e31ef846ecee102703cb8c92);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - Maker 추가

# %%
map = folium.Map(location=[37.52272, 126.905131], zoom_start=14)       # 영등포역
folium.Marker(
    location=[37.515556, 126.907778],            # WGS94 죄표계: 위도(latitude), 경도(longitude)
    tooltip='영등포역',
    popup=folium.Popup('서울시 영등포구 경인로 846', max_width=200)
).add_to(map)
folium.Marker(
    location=[37.52272, 126.905131],            # WGS94 죄표계: 위도(latitude), 경도(longitude)
    tooltip='영등포시장역',
    popup=folium.Popup('서울시 영등포구 양산로 200', max_width=200)
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9cfe8fc2b0941dd7521a27f597b0006 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9cfe8fc2b0941dd7521a27f597b0006&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9cfe8fc2b0941dd7521a27f597b0006 = L.map(
#                 &quot;map_b9cfe8fc2b0941dd7521a27f597b0006&quot;,
#                 {
#                     center: [37.52272, 126.905131],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0af6ee08cea4698f490405ca1503a3e6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b9cfe8fc2b0941dd7521a27f597b0006);
#
#
#             var marker_ee965a54dbb3cae78e458c36623ab3bb = L.marker(
#                 [37.515556, 126.907778],
#                 {}
#             ).addTo(map_b9cfe8fc2b0941dd7521a27f597b0006);
#
#
#         var popup_9abcd6be3cf16fdfe9089d4dc3b4dbbf = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_26adc176040c3e1367b085eb43ce5bf5 = $(`&lt;div id=&quot;html_26adc176040c3e1367b085eb43ce5bf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시 영등포구 경인로 846&lt;/div&gt;`)[0];
#                 popup_9abcd6be3cf16fdfe9089d4dc3b4dbbf.setContent(html_26adc176040c3e1367b085eb43ce5bf5);
#
#
#
#         marker_ee965a54dbb3cae78e458c36623ab3bb.bindPopup(popup_9abcd6be3cf16fdfe9089d4dc3b4dbbf)
#         ;
#
#
#
#
#             marker_ee965a54dbb3cae78e458c36623ab3bb.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_871621174f138a16c7d765b8f487e305 = L.marker(
#                 [37.52272, 126.905131],
#                 {}
#             ).addTo(map_b9cfe8fc2b0941dd7521a27f597b0006);
#
#
#         var popup_d7aaf05c64efb7dc48a61347786b1ee8 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_af09f16e46c2ae1031d2ae2e305683c3 = $(`&lt;div id=&quot;html_af09f16e46c2ae1031d2ae2e305683c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시 영등포구 양산로 200&lt;/div&gt;`)[0];
#                 popup_d7aaf05c64efb7dc48a61347786b1ee8.setContent(html_af09f16e46c2ae1031d2ae2e305683c3);
#
#
#
#         marker_871621174f138a16c7d765b8f487e305.bindPopup(popup_d7aaf05c64efb7dc48a61347786b1ee8)
#         ;
#
#
#
#
#             marker_871621174f138a16c7d765b8f487e305.bindTooltip(
#                 `&lt;div&gt;
#                      영등포시장역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# - 다양한  Marker

# %%
map = folium.Map(location=[37.52272, 126.905131], zoom_start=14)      
folium.Marker(
    location=[37.515556, 126.907778],            # WGS94 죄표계: 위도(latitude), 경도(longitude)
    tooltip='영등포역',
    popup=folium.Popup('서울시 영등포구 경인로 846', max_width=200)
).add_to(map)
folium.Marker(
    location=[37.52272, 126.905131],            # WGS94 죄표계: 위도(latitude), 경도(longitude)
    tooltip='영등포시장역',
    popup=folium.Popup('서울시 영등포구 양산로 200', max_width=200),
    icon=folium.Icon(color='green')
).add_to(map)
folium.Circle(
    location=[37.532003, 126.914072], tooltip='국회의사당',
    radius=100, color='crimson', fill=True,
    popup=folium.Popup('서울특별시 영등포구 여의도동 1', max_width=200)
).add_to(map)
folium.CircleMarker(
    location=[37.525317, 126.896606], tooltip='영등포구청',
    radius=15, color='#3186cc', fill=True,
    popup=folium.Popup('서울특별시 영등포구 당산동3가 385-1', max_width=200)
).add_to(map)
title_html = '<h3 align="center" style="font-size:20px">학원근처 유명 지점</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1f2b755742f11feb7dc35887b166b9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;학원근처 유명 지점&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1f2b755742f11feb7dc35887b166b9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1f2b755742f11feb7dc35887b166b9c = L.map(
#                 &quot;map_c1f2b755742f11feb7dc35887b166b9c&quot;,
#                 {
#                     center: [37.52272, 126.905131],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4df9101f65cfa6292f52836db19bb88 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c1f2b755742f11feb7dc35887b166b9c);
#
#
#             var marker_e8898d355f4ced3ad5b33be4ff3321fb = L.marker(
#                 [37.515556, 126.907778],
#                 {}
#             ).addTo(map_c1f2b755742f11feb7dc35887b166b9c);
#
#
#         var popup_3f196521bbd00aad279b4153a7b1a94e = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_ccd9df082540ff188fd33793e790df90 = $(`&lt;div id=&quot;html_ccd9df082540ff188fd33793e790df90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시 영등포구 경인로 846&lt;/div&gt;`)[0];
#                 popup_3f196521bbd00aad279b4153a7b1a94e.setContent(html_ccd9df082540ff188fd33793e790df90);
#
#
#
#         marker_e8898d355f4ced3ad5b33be4ff3321fb.bindPopup(popup_3f196521bbd00aad279b4153a7b1a94e)
#         ;
#
#
#
#
#             marker_e8898d355f4ced3ad5b33be4ff3321fb.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2ba4ab796bb925aed484fa4a0a787e0a = L.marker(
#                 [37.52272, 126.905131],
#                 {}
#             ).addTo(map_c1f2b755742f11feb7dc35887b166b9c);
#
#
#             var icon_d9b451285e88625c02e32f4b166c42d3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2ba4ab796bb925aed484fa4a0a787e0a.setIcon(icon_d9b451285e88625c02e32f4b166c42d3);
#
#
#         var popup_ac601ceeac14b59ac63b51ade312793a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_86fb9201ec0f3b919ff2632ef73e3524 = $(`&lt;div id=&quot;html_86fb9201ec0f3b919ff2632ef73e3524&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시 영등포구 양산로 200&lt;/div&gt;`)[0];
#                 popup_ac601ceeac14b59ac63b51ade312793a.setContent(html_86fb9201ec0f3b919ff2632ef73e3524);
#
#
#
#         marker_2ba4ab796bb925aed484fa4a0a787e0a.bindPopup(popup_ac601ceeac14b59ac63b51ade312793a)
#         ;
#
#
#
#
#             marker_2ba4ab796bb925aed484fa4a0a787e0a.bindTooltip(
#                 `&lt;div&gt;
#                      영등포시장역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_bcf74ff9f67daf43f3a876736e1d80aa = L.circle(
#                 [37.532003, 126.914072],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c1f2b755742f11feb7dc35887b166b9c);
#
#
#         var popup_662a350ec54a6cb679564f66a7ee6f52 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_e0f4ebd09a3011553b01b1ab598be5af = $(`&lt;div id=&quot;html_e0f4ebd09a3011553b01b1ab598be5af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 여의도동 1&lt;/div&gt;`)[0];
#                 popup_662a350ec54a6cb679564f66a7ee6f52.setContent(html_e0f4ebd09a3011553b01b1ab598be5af);
#
#
#
#         circle_bcf74ff9f67daf43f3a876736e1d80aa.bindPopup(popup_662a350ec54a6cb679564f66a7ee6f52)
#         ;
#
#
#
#
#             circle_bcf74ff9f67daf43f3a876736e1d80aa.bindTooltip(
#                 `&lt;div&gt;
#                      국회의사당
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_18b0f482bfb08a7a95872f4008c6c287
